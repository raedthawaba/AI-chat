# %% [markdown]
# # Arabic AI Engine - Production Ready Setup
# هذا الملف يقوم بتجهيز وتشغيل محرك الذكاء الاصطناعي العربي مباشرة على Google Colab.

# %%
# 1. تثبيت المكتبات المطلوبة
# !pip install sentencepiece torch tqdm pyyaml

# %%
# 2. إعداد المسارات وتشغيل الدردشة المباشرة
import os
import sys

# إضافة مجلد المشروع للمسارات
os.environ['PYTHONPATH'] = os.getcwd()

print("Starting Arabic AI Engine Chat...")
# !python3 inference/chat.py
